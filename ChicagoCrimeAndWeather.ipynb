# %%
import requests
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timezone
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
from google.cloud import bigquery
client = bigquery.Client()

# %%
sql="""  SELECT
    TIMESTAMP_TRUNC(date,
      DAY) AS date,
    year,
    COUNT(1) AS incidents
  FROM
    `bigquery-public-data.chicago_crime.crime`
  WHERE
    primary_type IN ('BATTERY',
      'ASSAULT')
    AND year BETWEEN 2014
    AND 2016
  GROUP BY
    date,
    year"""

df = client.query(sql).to_dataframe()
df.head()
# Out:
#                        date  year  incidents
# 0 2014-08-31 00:00:00+00:00  2014        257
# 1 2014-06-07 00:00:00+00:00  2014        259
# 2 2014-07-13 00:00:00+00:00  2014        259
# 3 2014-05-25 00:00:00+00:00  2014        260
# 4 2014-08-03 00:00:00+00:00  2014        261

# %%
df['date']=pd.to_datetime(df['date'])
df.head()
# Out:
#                        date  year  incidents
# 0 2014-08-31 00:00:00+00:00  2014        257
# 1 2014-06-07 00:00:00+00:00  2014        259
# 2 2014-07-13 00:00:00+00:00  2014        259
# 3 2014-05-25 00:00:00+00:00  2014        260
# 4 2014-08-03 00:00:00+00:00  2014        261

# %%
sql="""SELECT
    TIMESTAMP_TRUNC(TIMESTAMP(CONCAT(year, '-', mo, '-', da)),
      DAY) AS date,
    year,
    PERCENT_RANK() OVER (PARTITION BY year ORDER BY AVG(temp)) AS rank,
    AVG(temp) AS temperature
  FROM
    `bigquery-public-data.noaa_gsod.gsod*` AS w
  JOIN
    `bigquery-public-data.noaa_gsod.stations` AS s
  ON
    w.stn = s.usaf
    AND s.name = "CHICAGO O'HARE INTERNATIONAL"
  WHERE
    w._TABLE_SUFFIX BETWEEN '2014'
    AND '2016'
  GROUP BY
    date,
    year"""

weather_df = client.query(sql).to_dataframe()
weather_df.head()
# Out:
#                        date  year      rank  temperature
# 0 2014-01-06 00:00:00+00:00  2014  0.000000         -7.7
# 1 2014-01-07 00:00:00+00:00  2014  0.002747         -7.3
# 2 2014-01-28 00:00:00+00:00  2014  0.005495         -5.2
# 3 2014-02-07 00:00:00+00:00  2014  0.008242          2.3
# 4 2014-01-08 00:00:00+00:00  2014  0.010989          2.7

# %%
merged_data = pd.merge(df, weather_df, left_on='date', right_on='date')
merged_data
# Out:
#                           date  year_x  incidents year_y      rank  \
# 0    2014-08-31 00:00:00+00:00    2014        257   2014  0.945055
# 1    2014-06-07 00:00:00+00:00    2014        259   2014  0.829670
# 2    2014-07-13 00:00:00+00:00    2014        259   2014  0.931319
# 3    2014-05-25 00:00:00+00:00    2014        260   2014  0.725275
# 4    2014-08-03 00:00:00+00:00    2014        261   2014  0.925824
# 5    2014-05-11 00:00:00+00:00    2014        261   2014  0.752747
# 6    2014-01-01 00:00:00+00:00    2014        263   2014  0.085165
# 7    2014-09-28 00:00:00+00:00    2014        264   2014  0.686813
# 8    2014-07-05 00:00:00+00:00    2014        264   2014  0.791209
# 9    2014-07-06 00:00:00+00:00    2014        266   2014  0.881868
# 10   2014-05-18 00:00:00+00:00    2014        268   2014  0.590659
# 11   2014-08-09 00:00:00+00:00    2014        271   2014  0.884615
# 1092 2016-06-12 00:00:00+00:00    2016        252   2016  0.761644
# 1093 2016-08-14 00:00:00+00:00    2016        253   2016  0.895890
# 1094 2016-06-04 00:00:00+00:00    2016        253   2016  0.709589
# 1095 2016-08-28 00:00:00+00:00    2016        255   2016  0.906849
#
#       temperature
# 0            76.2
# 1            71.1
# 2            75.8
# 3            66.2
# 4            75.4
# 5            67.2
# 6            15.8
# 7            64.9
# 8            69.2
# 9            73.0
# 10           56.4
# 11           73.5
# 12           71.6
# 13           75.4
# 14           77.4
# 15           -7.7
# 16           -7.3
# 17            7.7
# 18           18.6
# 19           -5.2
# 20            4.3
# 21           33.5
# 22            5.3
# 23            4.8
# 24           17.1
# 25           20.9
# 26            2.7
# 27           10.4
# 28            7.9
# 29           43.7
# ...           ...
# 1066         57.6
# 1067         54.7
# 1068         71.9
# 1069         74.1
# 1070         74.7
# 1071         70.1
# 1072         73.6
# 1073         73.9
# 1074         75.7
# 1075         66.2
# 1076         65.8
# 1077         75.5
# 1078         73.2
# 1079         56.2
# 1080         78.5
# 1081         59.8
# 1082         74.7
# 1083         82.4
# 1084         69.1
# 1085         72.3
# 1086         71.7
# 1087         81.3
# 1088         68.5
# 1089         66.4
# 1090         55.0
# 1091         68.5
# 1092         71.4
# 1093         76.7
# 1094         68.8
# 1095         76.9
#
# [1096 rows x 6 columns]

# %%
fig = plt.figure(figsize=(16,9))
plt.scatter(merged_data['temperature'],merged_data['incidents'])
plt.title('Crime Incidents vs Temperature from 2014 - 2016')
plt.ylabel("Crime Incidents")
plt.xlabel("Temperature")
# Out:
# Text(0.5,0,'Temperature')

# %%
sql="""  SELECT
    TIMESTAMP_TRUNC(date,
      DAY) AS date,
    year,
    COUNT(1) AS incidents
  FROM
    `bigquery-public-data.chicago_crime.crime`
  WHERE
    primary_type IN ('BATTERY',
      'ASSAULT')
    AND year BETWEEN 2011
    AND 2013
  GROUP BY
    date,
    year"""

df = client.query(sql).to_dataframe()
df.head()
# Out:
#                        date  year  incidents
# 0 2011-04-11 00:00:00+00:00  2011        256
# 1 2011-07-22 00:00:00+00:00  2011        257
# 2 2011-04-13 00:00:00+00:00  2011        257
# 3 2011-07-12 00:00:00+00:00  2011        257
# 4 2011-09-12 00:00:00+00:00  2011        257

# %%
sql="""SELECT
    TIMESTAMP_TRUNC(TIMESTAMP(CONCAT(year, '-', mo, '-', da)),
      DAY) AS date,
    year,
    PERCENT_RANK() OVER (PARTITION BY year ORDER BY AVG(temp)) AS rank,
    AVG(temp) AS temperature
  FROM
    `bigquery-public-data.noaa_gsod.gsod*` AS w
  JOIN
    `bigquery-public-data.noaa_gsod.stations` AS s
  ON
    w.stn = s.usaf
    AND s.name = "CHICAGO O'HARE INTERNATIONAL"
  WHERE
    w._TABLE_SUFFIX BETWEEN '2011'
    AND '2013'
  GROUP BY
    date,
    year"""

weather_df = client.query(sql).to_dataframe()
weather_df.head()
# Out:
#                        date  year      rank  temperature
# 0 2011-02-10 00:00:00+00:00  2011  0.000000          2.4
# 1075 2013-06-25 00:00:00+00:00    2013        239   2013  0.862637
# 1076 2013-08-24 00:00:00+00:00    2013        239   2013  0.848901
# 1077 2013-06-02 00:00:00+00:00    2013        240   2013  0.574176
# 1078 2013-03-16 00:00:00+00:00    2013        240   2013  0.252747
# 1079 2013-08-28 00:00:00+00:00    2013        240   2013  0.978022
# 1080 2013-05-14 00:00:00+00:00    2013        241   2013  0.700549
# 1081 2013-07-06 00:00:00+00:00    2013        241   2013  0.906593
# 1082 2013-03-31 00:00:00+00:00    2013        242   2013  0.494505
# 1083 2013-06-07 00:00:00+00:00    2013        242   2013  0.585165
# 1084 2013-06-15 00:00:00+00:00    2013        242   2013  0.722527
# 1085 2013-06-13 00:00:00+00:00    2013        244   2013  0.725275
# 1086 2013-04-30 00:00:00+00:00    2013        245   2013  0.780220
# 1087 2013-05-16 00:00:00+00:00    2013        245   2013  0.780220
# 1088 2013-05-04 00:00:00+00:00    2013        246   2013  0.560440
# 1089 2013-08-03 00:00:00+00:00    2013        246   2013  0.868132
# 1090 2013-05-29 00:00:00+00:00    2013        247   2013  0.804945
# 1091 2013-07-15 00:00:00+00:00    2013        248   2013  0.967033
# 1092 2013-06-19 00:00:00+00:00    2013        248   2013  0.667582
# 1093 2013-09-07 00:00:00+00:00    2013        252   2013  0.920330
# 1094 2013-08-04 00:00:00+00:00    2013        253   2013  0.755495
# 1095 2013-07-22 00:00:00+00:00    2013        253   2013  0.920330
#
#       temperature
# 0            62.4
# 1            80.5
# 2            49.9
# 3            80.5
# 4            73.6
# 5            73.8
# 6            69.1
# 7            80.1
# 8            75.6
# 9            78.3
# 10           85.5
# 11           50.0
# 12           69.0
# 13           73.0
# 14           74.0
# 15           53.4
# 16           61.5
# 17           74.0
# 18           70.8
# 19           58.5
# 20           73.5
# 21           68.5
# 22           72.1
# 23           78.7
# 24           57.0
# 25           43.4
# 26           82.4
# 27           73.2
# 28           47.5
# 29           69.3
# ...           ...
# 1066         86.8
# 1067         39.1
# 1068         72.8
# 1069         70.6
# 1070         57.7
# 1071         50.3
# 1072         70.1
# 1073         60.7
# 1074         65.1
# 1075         73.0
# 1076         72.7
# 1077         57.5
# 1078         33.0
# 1079         81.0
# 1080         65.5
# 1081         75.3
# 1082         49.3
# 1083         57.9
# 1084         66.7
# 1085         66.9
# 1086         69.6
# 1087         69.6
# 1088         55.4
# 1089         73.8
# 1090         71.1
# 1091         79.8
# 1092         63.5
# 1093         76.3
# 1094         68.6
# 1095         76.3
#
# [1096 rows x 6 columns]

# %%
fig = plt.figure(figsize=(16,9))
plt.scatter(merged_data['temperature'],merged_data['incidents'])
plt.title('Crime Incidents vs Temperature from 2011 - 2013')
plt.ylabel("Crime Incidents")
plt.xlabel("Temperature")
# Out:
# Text(0.5,0,'Temperature')

# %%
fig = plt.figure(figsize=(16,9))
plt.scatter(merged_data['temperature'],merged_data['incidents'])
plt.title('Crime Incidents vs Temperature from 2011 - 2013')
plt.ylabel("Crime Incidents")
plt.xlabel("Temperature")
# Out:
# Text(0.5,0,'Temperature')
